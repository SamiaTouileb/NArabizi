# %%
import numpy as np
import pandas as pd
import os
import itertools
from collections import Counter
from transformers import BertTokenizer

import sys
sys.path.append("..")
import utils.utils as utils
from data_preparation.data_preparation_pos import read_conll

# %%
import logging
logging.getLogger("transformers.tokenization_utils_base").setLevel(logging.ERROR)

# %% [markdown]
# ### PoS

# %%
model_name = "bert-base-multilingual-cased"
tokenizer = BertTokenizer.from_pretrained(model_name)

# %%
def pos_stats(info, table, tokenizer):
    file_path = info["file_path"]
    lang_name = info["lang_name"]
    dataset = info["dataset"]
    d = {}
    
    conllu_data = read_conll(file_path)
    examples = [{"id": sent_id, "tokens": tokens, "tags": tags} for sent_id, tokens, tags in zip(conllu_data[0], 
                                                                                                 conllu_data[1],
                                                                                                 conllu_data[2])]
    
    # Number of examples in dataset
    if table["language"].isna().all() or lang_name not in table["language"].values:
        d["language"] = lang_name
        index = table.index[table["language"].isna()][0]
    else:
        index = table.index[table["language"] == lang_name][0]
    d[dataset + "_examples"] = [len(examples)]
    
    # Avg tokens
    tokens, lengths = [], []
    for e in examples:
        tokenized = tokenizer.subword_tokenize(e["tokens"], e["tags"])[0]
        tokens.extend(tokenized)
        lengths.append(len(tokenized))
    d[dataset + "_avg_tokens"] = [np.array(lengths).mean()]
    
    # Hapaxes
    counts = np.array(list(Counter(tokens).items()))
    hapaxes = counts[counts[:,1] == "1"][:,0]
    d[dataset + "_hapaxes"] = [len(hapaxes)]
    d[dataset + "_hapaxes(%)"] = [len(hapaxes) / len(tokens) * 100]
    
    # Unknown
    unk = (np.array(tokens) == "[UNK]").sum()
    d[dataset + "_unknown"] = [unk]
    d[dataset + "_unknown(%)"] = [unk / len(tokens) * 100]
    
    table.update(pd.DataFrame(d, index=[index]))
    return table

# %%
names = ["train", "dev", "test"]
names_examples = (np.array(names, dtype=object) + "_examples").tolist()
names_avg = (np.array(names, dtype=object) + "_avg_tokens").tolist()
names_hapaxes = np.array(list(itertools.product(names, ["_hapaxes", "_hapaxes(%)"])), dtype=object)
names_hapaxes = (names_hapaxes[:,0] + names_hapaxes[:,1]).tolist()
names_unknown = np.array(list(itertools.product(names, ["_unknown", "_unknown(%)"])), dtype=object)
names_unknown = (names_unknown[:,0] + names_unknown[:,1]).tolist()
colnames = ["language"] + names_examples + names_avg + names_hapaxes + names_unknown
values = np.empty((len(os.listdir("../data/ud/")), len(colnames)))
values[:] = np.nan

pos_table = utils.run_through_data("../data/ud/", 
                                   pos_stats, 
                                   pd.DataFrame(values, columns=colnames), 
                                   tokenizer=tokenizer)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=43.0), HTML(value='')))

# %%
pos_table = utils.order_table(pos_table)
pos_table = pos_table.astype(dict.fromkeys([col for col in pos_table.columns[1:] if "%" not in col and "avg" not in col], 
                                           pd.Int64Dtype())) # Convert to int
pos_table
# Out:
#       language  train_examples  dev_examples  test_examples  train_avg_tokens  \
# 0    Bulgarian            8907          1115           1116         25.908387
# 1      English            4287           784           1000         22.703056
# 2      Russian            3850           579           1000         36.337662
# 3       Slovak            8483          1060           1061         18.328422
# 4     Croatian            6914           960           1136         39.301417
# 5      Chinese            3997           500           1000         37.077058
# 6   Vietnamese            1400           800            800         20.641429
# 7         Thai            <NA>          <NA>           1000               NaN
# 8      Finnish           12217          1364           1000         30.006548
# 9       Basque            5396          1798           1799         25.981282
# 10    Japanese            7027           501           1000         34.953181
# 11      Korean           23010          2066           1000         29.248110
# 12     Turkish            3664           988           1000         21.805950
# 13      Arabic            6075           909           1000         79.058272
# 14      Hebrew            5241           484            491         61.150162
#
#     dev_avg_tokens  test_avg_tokens  train_hapaxes  train_hapaxes(%)  \
# 0        26.656502        26.198029            766          0.331938
# 1        23.579082        24.394000           4158          4.272152
# 2        38.015544        33.806000           2311          1.651894
# 3        23.462264        24.967955           1805          1.160921
# 4        40.905208        37.956866           2646          0.973761
# 5        38.180000        33.630000           2260          1.524997
# 6        19.972500        20.782500            344          1.190394
# 7              NaN        69.424000           <NA>               NaN
# 8        29.886364        33.789000           3119          0.850814
# 9        25.706897        26.115064           2169          1.547131
# 10       35.548902        41.660000           1668          0.679109
# 11       29.085189        33.409000           1432          0.212779
# 12       21.434211        33.751000           1138          1.424334
# 13       69.865787        36.166000            400          0.083285
# 14       54.237603        58.541752            188          0.058661
#
#     dev_hapaxes  dev_hapaxes(%)  test_hapaxes  test_hapaxes(%)  train_unknown  \
# 0          1014        3.411614           928         3.174060              0
# 1          2156       11.662880          3439        14.097729            800
# 2          2335       10.608332          1965         5.812578            853
# 3          1863        7.490953          1641         6.194557           2106
# 4          1769        4.504826          1790         4.151302             21
# 5          1202        6.296490          1366         4.061850            126
# 6           372        2.328201           390         2.345724             15
# 7          <NA>             NaN           184         0.265038           <NA>
# 8          1577        3.868515          2033         6.016751            840
# 9          1750        3.786158          1767         3.761095             14
# 10         1021        5.732734          1027         2.465194            548
# 11          439        0.730571           721         2.158101           1552
# 12         1042        4.920433          1730         5.125774              0
# 13          395        0.621969           512         1.415694              0
# 14          439        1.672317           443         1.541191              0
#
#     train_unknown(%)  dev_unknown  dev_unknown(%)  test_unknown  \
# 0           0.000000            0        0.000000             0
# 1           0.821963          117        0.632911           116
# 2           0.609721          149        0.676934            91
# 3           1.354515           59        0.237234            37
# 4           0.007728            1        0.002547             0
# 5           0.085022           14        0.073337           195
# 6           0.051907            1        0.006259             1
# 7                NaN         <NA>             NaN           127
# 8           0.229139           80        0.196247           195
# 9           0.009986            3        0.006491             3
# 10          0.223113           42        0.235823             4
# 11          0.230610           77        0.128141            92
# 12          0.000000            0        0.000000             0
# 13          0.000000            0        0.000000             0
# 14          0.000000            0        0.000000             0
#
#     test_unknown(%)
# 0          0.000000
# 1          0.475527
# 2          0.269183
# 3          0.139670
# 4          0.000000
# 5          0.579839
# 6          0.006015
# 7          0.182934
# 8          0.577111
# 9          0.006386
# 10         0.009602
# 11         0.275375
# 12         0.000000
# 13         0.000000
# 14         0.000000

# %% [markdown]
# Export excel

# %%
pos_table.to_excel("pos_basic_stats.xlsx", index=False)

# %% [markdown]
# Export latex

# %%
colnames_percentage = []
colnames_avg = []

for col in pos_table.columns:
    if "%" in col:
        colnames_percentage.append(col)
    elif "avg" in col:
        colnames_avg.append(col)

pos_table[colnames_percentage] = pos_table[colnames_percentage].applymap(lambda x: "{:.2f}".format(x))
pos_table[colnames_avg] = pos_table[colnames_avg].applymap(lambda x: "{:.1f}".format(x))
pos_table = pos_table.replace(np.nan, "-")
pos_table = pos_table.replace("nan", "-")
pos_table
# Out:
#       language train_examples dev_examples  test_examples train_avg_tokens  \
# 0    Bulgarian           8907         1115           1116             25.9
# 1      English           4287          784           1000             22.7
# 2      Russian           3850          579           1000             36.3
# 3       Slovak           8483         1060           1061             18.3
# 4     Croatian           6914          960           1136             39.3
# 5      Chinese           3997          500           1000             37.1
# 6   Vietnamese           1400          800            800             20.6
# 7         Thai              -            -           1000                -
# 8      Finnish          12217         1364           1000             30.0
# 9       Basque           5396         1798           1799             26.0
# 10    Japanese           7027          501           1000             35.0
# 11      Korean          23010         2066           1000             29.2
# 12     Turkish           3664          988           1000             21.8
# 13      Arabic           6075          909           1000             79.1
# 14      Hebrew           5241          484            491             61.2
#
#    dev_avg_tokens test_avg_tokens train_hapaxes train_hapaxes(%) dev_hapaxes  \
# 0            26.7            26.2           766             0.33        1014
# 1            23.6            24.4          4158             4.27        2156
# 2            38.0            33.8          2311             1.65        2335
# 3            23.5            25.0          1805             1.16        1863
# 4            40.9            38.0          2646             0.97        1769
# 5            38.2            33.6          2260             1.52        1202
# 6            20.0            20.8           344             1.19         372
# 7               -            69.4             -                -           -
# 8            29.9            33.8          3119             0.85        1577
# 9            25.7            26.1          2169             1.55        1750
# 10           35.5            41.7          1668             0.68        1021
# 11           29.1            33.4          1432             0.21         439
# 12           21.4            33.8          1138             1.42        1042
# 13           69.9            36.2           400             0.08         395
# 14           54.2            58.5           188             0.06         439
#
#    dev_hapaxes(%)  test_hapaxes test_hapaxes(%) train_unknown  \
# 0            3.41           928            3.17             0
# 1           11.66          3439           14.10           800
# 2           10.61          1965            5.81           853
# 3            7.49          1641            6.19          2106
# 4            4.50          1790            4.15            21
# 5            6.30          1366            4.06           126
# 6            2.33           390            2.35            15
# 7               -           184            0.27             -
# 8            3.87          2033            6.02           840
# 9            3.79          1767            3.76            14
# 10           5.73          1027            2.47           548
# 11           0.73           721            2.16          1552
# 12           4.92          1730            5.13             0
# 13           0.62           512            1.42             0
# 14           1.67           443            1.54             0
#
#    train_unknown(%) dev_unknown dev_unknown(%)  test_unknown test_unknown(%)
# 0              0.00           0           0.00             0            0.00
# 1              0.82         117           0.63           116            0.48
# 2              0.61         149           0.68            91            0.27
# 3              1.35          59           0.24            37            0.14
# 4              0.01           1           0.00             0            0.00
# 5              0.09          14           0.07           195            0.58
# 6              0.05           1           0.01             1            0.01
# 7                 -           -              -           127            0.18
# 8              0.23          80           0.20           195            0.58
# 9              0.01           3           0.01             3            0.01
# 10             0.22          42           0.24             4            0.01
# 11             0.23          77           0.13            92            0.28
# 12             0.00           0           0.00             0            0.00
# 13             0.00           0           0.00             0            0.00
# 14             0.00           0           0.00             0            0.00

# %% [markdown]
# Since the table is too big, we'll split it

# %%
utils.convert_table_to_latex(pos_table.iloc[:,:7])
# Out:
# \fusional{Fusional} & Bulgarian & 8907 & 1115 & 1116 & 25.9 & 26.7 & 26.2\\
# \fusional{Fusional} & English & 4287 & 784 & 1000 & 22.7 & 23.6 & 24.4\\
# \fusional{Fusional} & Russian & 3850 & 579 & 1000 & 36.3 & 38.0 & 33.8\\
# \fusional{Fusional} & Slovak & 8483 & 1060 & 1061 & 18.3 & 23.5 & 25.0\\
# \fusional{Fusional} & Croatian & 6914 & 960 & 1136 & 39.3 & 40.9 & 38.0\\
# \isolating{Isolating} & Chinese & 3997 & 500 & 1000 & 37.1 & 38.2 & 33.6\\
# \isolating{Isolating} & Vietnamese & 1400 & 800 & 800 & 20.6 & 20.0 & 20.8\\
# \isolating{Isolating} & Thai & - & - & 1000 & - & - & 69.4\\
# \agglutinative{Agglutinative} & Finnish & 12217 & 1364 & 1000 & 30.0 & 29.9 & 33.8\\
# \agglutinative{Agglutinative} & Basque & 5396 & 1798 & 1799 & 26.0 & 25.7 & 26.1\\
# \agglutinative{Agglutinative} & Japanese & 7027 & 501 & 1000 & 35.0 & 35.5 & 41.7\\
# \agglutinative{Agglutinative} & Korean & 23010 & 2066 & 1000 & 29.2 & 29.1 & 33.4\\
# \agglutinative{Agglutinative} & Turkish & 3664 & 988 & 1000 & 21.8 & 21.4 & 33.8\\
# \introflexive{Introflexive} & Arabic & 6075 & 909 & 1000 & 79.1 & 69.9 & 36.2\\
# \introflexive{Introflexive} & Hebrew & 5241 & 484 & 491 & 61.2 & 54.2 & 58.5\\
#                             group    language train_examples dev_examples  \
# 0             \fusional{Fusional}   Bulgarian           8907         1115
# 1             \fusional{Fusional}     English           4287          784
# 2             \fusional{Fusional}     Russian           3850          579
# 3             \fusional{Fusional}      Slovak           8483         1060
# 4             \fusional{Fusional}    Croatian           6914          960
# 5           \isolating{Isolating}     Chinese           3997          500
# 6           \isolating{Isolating}  Vietnamese           1400          800
# 7           \isolating{Isolating}        Thai              -            -
# 8   \agglutinative{Agglutinative}     Finnish          12217         1364
# 9   \agglutinative{Agglutinative}      Basque           5396         1798
# 10  \agglutinative{Agglutinative}    Japanese           7027          501
# 11  \agglutinative{Agglutinative}      Korean          23010         2066
# 12  \agglutinative{Agglutinative}     Turkish           3664          988
# 13    \introflexive{Introflexive}      Arabic           6075          909
# 14    \introflexive{Introflexive}      Hebrew           5241          484
#
#     test_examples train_avg_tokens dev_avg_tokens test_avg_tokens
# 0            1116             25.9           26.7            26.2
# 1            1000             22.7           23.6            24.4
# 2            1000             36.3           38.0            33.8
# 3            1061             18.3           23.5            25.0
# 4            1136             39.3           40.9            38.0
# 5            1000             37.1           38.2            33.6
# 6             800             20.6           20.0            20.8
# 7            1000                -              -            69.4
# 8            1000             30.0           29.9            33.8
# 9            1799             26.0           25.7            26.1
# 10           1000             35.0           35.5            41.7
# 11           1000             29.2           29.1            33.4
# 12           1000             21.8           21.4            33.8
# 13           1000             79.1           69.9            36.2
# 14            491             61.2           54.2            58.5

# %%
utils.convert_table_to_latex(pos_table[["language"] + pos_table.columns[7:13].tolist()])
# Out:
# \fusional{Fusional} & Bulgarian & 766 & 0.33 & 1014 & 3.41 & 928 & 3.17\\
# \fusional{Fusional} & English & 4158 & 4.27 & 2156 & 11.66 & 3439 & 14.10\\
# \fusional{Fusional} & Russian & 2311 & 1.65 & 2335 & 10.61 & 1965 & 5.81\\
# \fusional{Fusional} & Slovak & 1805 & 1.16 & 1863 & 7.49 & 1641 & 6.19\\
# \fusional{Fusional} & Croatian & 2646 & 0.97 & 1769 & 4.50 & 1790 & 4.15\\
# \isolating{Isolating} & Chinese & 2260 & 1.52 & 1202 & 6.30 & 1366 & 4.06\\
# \isolating{Isolating} & Vietnamese & 344 & 1.19 & 372 & 2.33 & 390 & 2.35\\
# \isolating{Isolating} & Thai & - & - & - & - & 184 & 0.27\\
# \agglutinative{Agglutinative} & Finnish & 3119 & 0.85 & 1577 & 3.87 & 2033 & 6.02\\
# \agglutinative{Agglutinative} & Basque & 2169 & 1.55 & 1750 & 3.79 & 1767 & 3.76\\
# \agglutinative{Agglutinative} & Japanese & 1668 & 0.68 & 1021 & 5.73 & 1027 & 2.47\\
# \agglutinative{Agglutinative} & Korean & 1432 & 0.21 & 439 & 0.73 & 721 & 2.16\\
# \agglutinative{Agglutinative} & Turkish & 1138 & 1.42 & 1042 & 4.92 & 1730 & 5.13\\
# \introflexive{Introflexive} & Arabic & 400 & 0.08 & 395 & 0.62 & 512 & 1.42\\
# \introflexive{Introflexive} & Hebrew & 188 & 0.06 & 439 & 1.67 & 443 & 1.54\\
#                             group    language train_hapaxes train_hapaxes(%)  \
# 0             \fusional{Fusional}   Bulgarian           766             0.33
# 1             \fusional{Fusional}     English          4158             4.27
# 2             \fusional{Fusional}     Russian          2311             1.65
# 3             \fusional{Fusional}      Slovak          1805             1.16
# 4             \fusional{Fusional}    Croatian          2646             0.97
# 5           \isolating{Isolating}     Chinese          2260             1.52
# 6           \isolating{Isolating}  Vietnamese           344             1.19
# 7           \isolating{Isolating}        Thai             -                -
# 8   \agglutinative{Agglutinative}     Finnish          3119             0.85
# 9   \agglutinative{Agglutinative}      Basque          2169             1.55
# 10  \agglutinative{Agglutinative}    Japanese          1668             0.68
# 11  \agglutinative{Agglutinative}      Korean          1432             0.21
# 12  \agglutinative{Agglutinative}     Turkish          1138             1.42
# 13    \introflexive{Introflexive}      Arabic           400             0.08
# 14    \introflexive{Introflexive}      Hebrew           188             0.06
#
#    dev_hapaxes dev_hapaxes(%)  test_hapaxes test_hapaxes(%)
# 0         1014           3.41           928            3.17
# 1         2156          11.66          3439           14.10
# 2         2335          10.61          1965            5.81
# 3         1863           7.49          1641            6.19
# 4         1769           4.50          1790            4.15
# 5         1202           6.30          1366            4.06
# 6          372           2.33           390            2.35
# 7            -              -           184            0.27
# 8         1577           3.87          2033            6.02
# 9         1750           3.79          1767            3.76
# 10        1021           5.73          1027            2.47
# 11         439           0.73           721            2.16
# 12        1042           4.92          1730            5.13
# 13         395           0.62           512            1.42
# 14         439           1.67           443            1.54

# %%
utils.convert_table_to_latex(pos_table[["language"] + pos_table.columns[13:].tolist()])
# Out:
# \fusional{Fusional} & Bulgarian & 0 & 0.00 & 0 & 0.00 & 0 & 0.00\\
# \fusional{Fusional} & English & 800 & 0.82 & 117 & 0.63 & 116 & 0.48\\
# \fusional{Fusional} & Russian & 853 & 0.61 & 149 & 0.68 & 91 & 0.27\\
# \fusional{Fusional} & Slovak & 2106 & 1.35 & 59 & 0.24 & 37 & 0.14\\
# \fusional{Fusional} & Croatian & 21 & 0.01 & 1 & 0.00 & 0 & 0.00\\
# \isolating{Isolating} & Chinese & 126 & 0.09 & 14 & 0.07 & 195 & 0.58\\
# \isolating{Isolating} & Vietnamese & 15 & 0.05 & 1 & 0.01 & 1 & 0.01\\
# \isolating{Isolating} & Thai & - & - & - & - & 127 & 0.18\\
# \agglutinative{Agglutinative} & Finnish & 840 & 0.23 & 80 & 0.20 & 195 & 0.58\\
# \agglutinative{Agglutinative} & Basque & 14 & 0.01 & 3 & 0.01 & 3 & 0.01\\
# \agglutinative{Agglutinative} & Japanese & 548 & 0.22 & 42 & 0.24 & 4 & 0.01\\
# \agglutinative{Agglutinative} & Korean & 1552 & 0.23 & 77 & 0.13 & 92 & 0.28\\
# \agglutinative{Agglutinative} & Turkish & 0 & 0.00 & 0 & 0.00 & 0 & 0.00\\
# \introflexive{Introflexive} & Arabic & 0 & 0.00 & 0 & 0.00 & 0 & 0.00\\
# \introflexive{Introflexive} & Hebrew & 0 & 0.00 & 0 & 0.00 & 0 & 0.00\\
#                             group    language train_unknown train_unknown(%)  \
# 0             \fusional{Fusional}   Bulgarian             0             0.00
# 1             \fusional{Fusional}     English           800             0.82
# 2             \fusional{Fusional}     Russian           853             0.61
# 3             \fusional{Fusional}      Slovak          2106             1.35
# 4             \fusional{Fusional}    Croatian            21             0.01
# 5           \isolating{Isolating}     Chinese           126             0.09
# 6           \isolating{Isolating}  Vietnamese            15             0.05
# 7           \isolating{Isolating}        Thai             -                -
# 8   \agglutinative{Agglutinative}     Finnish           840             0.23
# 9   \agglutinative{Agglutinative}      Basque            14             0.01
# 10  \agglutinative{Agglutinative}    Japanese           548             0.22
# 11  \agglutinative{Agglutinative}      Korean          1552             0.23
# 12  \agglutinative{Agglutinative}     Turkish             0             0.00
# 13    \introflexive{Introflexive}      Arabic             0             0.00
# 14    \introflexive{Introflexive}      Hebrew             0             0.00
#
#    dev_unknown dev_unknown(%)  test_unknown test_unknown(%)
# 0            0           0.00             0            0.00
# 1          117           0.63           116            0.48
# 2          149           0.68            91            0.27
# 3           59           0.24            37            0.14
# 4            1           0.00             0            0.00
# 5           14           0.07           195            0.58
# 6            1           0.01             1            0.01
# 7            -              -           127            0.18
# 8           80           0.20           195            0.58
# 9            3           0.01             3            0.01
# 10          42           0.24             4            0.01
# 11          77           0.13            92            0.28
# 12           0           0.00             0            0.00
# 13           0           0.00             0            0.00
# 14           0           0.00             0            0.00

# %% [markdown]
# ### Sentiment

# %%
model_name = "bert-base-multilingual-cased"
tokenizer = ABSATokenizer.from_pretrained(model_name)

# %%
def sentiment_stats(info, table, tokenizer):
    file_path = info["file_path"]
    lang_name = info["lang_name"]
    dataset = info["dataset"]
    d = {}
    
    data = pd.read_csv(file_path, header=None)
    data.columns = ["sentiment", "review"]
    
    # Number of examples in dataset
    if table["language"].isna().all() or lang_name not in table["language"].values:
        d["language"] = lang_name
        index = table.index[table["language"].isna()][0]
    else:
        index = table.index[table["language"] == lang_name][0]
    d[dataset + "_examples"] = [data.shape[0]]
    
    # Avg tokens
    tokens, lengths = [], []
    for e in data["review"]:
        tokenized = tokenizer.encode(e)
        tokens.extend(tokenized)
        lengths.append(len(tokenized))
    d[dataset + "_avg_tokens"] = [np.array(lengths).mean()]
    
    # Hapaxes
    counts = np.array(list(Counter(tokens).items()))
    hapaxes = counts[counts[:,1] == 1][:,0]
    d[dataset + "_hapaxes"] = [len(hapaxes)]
    d[dataset + "_hapaxes(%)"] = [len(hapaxes) / len(tokens) * 100]
    
    # Unknown
    unk = (np.array(tokens) == 100).sum()
    d[dataset + "_unknown"] = [unk]
    d[dataset + "_unknown(%)"] = [unk / len(tokens) * 100]
    
    table.update(pd.DataFrame(d, index=[index]))
    return table

# %%
names = ["train", "dev", "test"]
names_examples = (np.array(names, dtype=object) + "_examples").tolist()
names_avg = (np.array(names, dtype=object) + "_avg_tokens").tolist()
names_hapaxes = np.array(list(itertools.product(names, ["_hapaxes", "_hapaxes(%)"])), dtype=object)
names_hapaxes = (names_hapaxes[:,0] + names_hapaxes[:,1]).tolist()
names_unknown = np.array(list(itertools.product(names, ["_unknown", "_unknown(%)"])), dtype=object)
names_unknown = (names_unknown[:,0] + names_unknown[:,1]).tolist()
colnames = ["language"] + names_examples + names_avg + names_hapaxes + names_unknown
values = np.empty((len(os.listdir("../data/ud/")), len(colnames)))
values[:] = np.nan

sentiment_table = utils.run_through_data("../data/sentiment/", 
                                   sentiment_stats, 
                                   pd.DataFrame(values, columns=colnames), 
                                   tokenizer=tokenizer)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=46.0), HTML(value='')))
# ../data/sentiment\ko\kosac-corpus-130808.csv is not a valid data path, skipping

# %%
sentiment_table = utils.order_table(sentiment_table)
sentiment_table = sentiment_table.astype(
    dict.fromkeys([col for col in sentiment_table.columns[1:] if "%" not in col and "avg" not in col], 
                  pd.Int64Dtype())
) # Convert to int
sentiment_table
# Out:
#       language  train_examples  dev_examples  test_examples  train_avg_tokens  \
# 0    Bulgarian            5412           838           1673         19.942905
# 1      English            6920           872           1821         27.659682
# 2      Russian            2938           424            867       1120.134786
# 3       Slovak            3724           532           1064         32.972610
# 4     Croatian            1507           214            437         55.202389
# 5      Chinese           19292          2756           5513         80.298258
# 6   Vietnamese            2384           331            685         35.752936
# 7         Thai            8103          1153           2344         52.782179
# 8      Finnish            1355           199            397         93.261255
# 9       Basque             789           113            227         21.449937
# 10    Japanese           10000          1000           2000        532.771500
# 11      Korean            3237           463            926         44.177634
# 12     Turkish             660            91            184       1217.525758
# 13      Arabic           35841          5134          10076        138.134957
# 14      Hebrew            8702          1240           2492         47.901977
#
#     dev_avg_tokens  test_avg_tokens  train_hapaxes  train_hapaxes(%)  \
# 0        18.220764        19.430962            599          0.554984
# 1        27.959862        27.584843           3257          1.701627
# 2      1122.966981       941.967705           2005          0.060925
# 3        32.325188        34.880639           1460          1.189022
# 4        56.742991        51.778032           1409          1.693713
# 5        79.469521        80.164339            606          0.039119
# 6        40.951662        37.435036           1026          1.203731
# 7        56.319167        56.366894           1445          0.337858
# 8        95.316583        92.488665           1704          1.348432
# 9        20.946903        20.682819            851          5.028362
# 10      541.247000       526.776000           3413          0.064061
# 11       39.241901        43.038877            445          0.311182
# 12     1284.901099      1234.081522           2851          0.354793
# 13      131.947215       138.387058            246          0.004969
# 14       48.304839        47.988764            391          0.093800
#
#     dev_hapaxes  dev_hapaxes(%)  test_hapaxes  test_hapaxes(%)  train_unknown  \
# 0           471        3.084681           556         1.710348             29
# 1          2416        9.909356          2876         5.725434            626
# 2          1838        0.386023          1879         0.230076          12547
# 3           990        5.756818          1143         3.079783            142
# 4           946        7.790497          1055         4.662571              2
# 5           856        0.390835           935         0.211564           6772
# 6           732        5.400221           797         3.108061            384
# 7           597        0.919367           894         0.676637           1384
# 8          1215        6.405525          1320         3.594967             15
# 9           461       19.476130           607        12.928647              0
# 10         1928        0.356214          2288         0.217170          16407
# 11          507        2.790467           448         1.124103            608
# 12         1894        1.619828          2049         0.902361           2272
# 13          249        0.036757           236         0.016925            697
# 14          539        0.899863           560         0.468274            260
#
#     train_unknown(%)  dev_unknown  dev_unknown(%)  test_unknown  \
# 0           0.026869            3        0.019648            10
# 1           0.327055           52        0.213281            99
# 2           0.381257         1321        0.277441          3288
# 3           0.115645           28        0.162819            51
# 4           0.002404            0        0.000000             0
# 5           0.437153         1133        0.517309          1734
# 6           0.450519           51        0.376245            60
# 7           0.323596          193        0.297216           390
# 8           0.011870            2        0.010544             2
# 9           0.000000            0        0.000000             0
# 10          0.307956         1539        0.284343          2825
# 11          0.425166           42        0.231163           184
# 12          0.282739          217        0.185587           695
# 13          0.014078           89        0.013138           257
# 14          0.062374           32        0.053424            69
#
#     test_unknown(%)
# 0          0.030762
# 1          0.197086
# 2          0.402603
# 3          0.137418
# 4          0.000000
# 5          0.392356
# 6          0.233982
# 7          0.295177
# 8          0.005447
# 9          0.000000
# 10         0.268141
# 11         0.461685
# 12         0.306072
# 13         0.018431
# 14         0.057698

# %% [markdown]
# Export excel

# %%
sentiment_table.to_excel("sentiment_basic_stats.xlsx", index=False)

# %% [markdown]
# Export latex (split into several tables)

# %%
colnames_percentage = []
colnames_avg = []

for col in sentiment_table.columns:
    if "%" in col:
        colnames_percentage.append(col)
    elif "avg" in col:
        colnames_avg.append(col)

sentiment_table[colnames_percentage] = sentiment_table[colnames_percentage].applymap(lambda x: "{:.2f}".format(x))
sentiment_table[colnames_avg] = sentiment_table[colnames_avg].applymap(lambda x: "{:.1f}".format(x))
sentiment_table = sentiment_table.replace(np.nan, "-")
sentiment_table = sentiment_table.replace("nan", "-")
sentiment_table
# Out:
#       language  train_examples  dev_examples  test_examples train_avg_tokens  \
# 0    Bulgarian            5412           838           1673             19.9
# 1      English            6920           872           1821             27.7
# 2      Russian            2938           424            867           1120.1
# 3       Slovak            3724           532           1064             33.0
# 4     Croatian            1507           214            437             55.2
# 5      Chinese           19292          2756           5513             80.3
# 6   Vietnamese            2384           331            685             35.8
# 7         Thai            8103          1153           2344             52.8
# 8      Finnish            1355           199            397             93.3
# 9       Basque             789           113            227             21.4
# 10    Japanese           10000          1000           2000            532.8
# 11      Korean            3237           463            926             44.2
# 12     Turkish             660            91            184           1217.5
# 13      Arabic           35841          5134          10076            138.1
# 14      Hebrew            8702          1240           2492             47.9
#
#    dev_avg_tokens test_avg_tokens  train_hapaxes train_hapaxes(%)  \
# 0            18.2            19.4            599             0.55
# 1            28.0            27.6           3257             1.70
# 2          1123.0           942.0           2005             0.06
# 3            32.3            34.9           1460             1.19
# 4            56.7            51.8           1409             1.69
# 5            79.5            80.2            606             0.04
# 6            41.0            37.4           1026             1.20
# 7            56.3            56.4           1445             0.34
# 8            95.3            92.5           1704             1.35
# 9            20.9            20.7            851             5.03
# 10          541.2           526.8           3413             0.06
# 11           39.2            43.0            445             0.31
# 12         1284.9          1234.1           2851             0.35
# 13          131.9           138.4            246             0.00
# 14           48.3            48.0            391             0.09
#
#     dev_hapaxes dev_hapaxes(%)  test_hapaxes test_hapaxes(%)  train_unknown  \
# 0           471           3.08           556            1.71             29
# 1          2416           9.91          2876            5.73            626
# 2          1838           0.39          1879            0.23          12547
# 3           990           5.76          1143            3.08            142
# 4           946           7.79          1055            4.66              2
# 5           856           0.39           935            0.21           6772
# 6           732           5.40           797            3.11            384
# 7           597           0.92           894            0.68           1384
# 8          1215           6.41          1320            3.59             15
# 9           461          19.48           607           12.93              0
# 10         1928           0.36          2288            0.22          16407
# 11          507           2.79           448            1.12            608
# 12         1894           1.62          2049            0.90           2272
# 13          249           0.04           236            0.02            697
# 14          539           0.90           560            0.47            260
#
#    train_unknown(%)  dev_unknown dev_unknown(%)  test_unknown test_unknown(%)
# 0              0.03            3           0.02            10            0.03
# 1              0.33           52           0.21            99            0.20
# 2              0.38         1321           0.28          3288            0.40
# 3              0.12           28           0.16            51            0.14
# 4              0.00            0           0.00             0            0.00
# 5              0.44         1133           0.52          1734            0.39
# 6              0.45           51           0.38            60            0.23
# 7              0.32          193           0.30           390            0.30
# 8              0.01            2           0.01             2            0.01
# 9              0.00            0           0.00             0            0.00
# 10             0.31         1539           0.28          2825            0.27
# 11             0.43           42           0.23           184            0.46
# 12             0.28          217           0.19           695            0.31
# 13             0.01           89           0.01           257            0.02
# 14             0.06           32           0.05            69            0.06

# %%
utils.convert_table_to_latex(sentiment_table.iloc[:,:7])
# Out:
# \fusional{Fusional} & Bulgarian & 5412 & 838 & 1673 & 19.9 & 18.2 & 19.4\\
# \fusional{Fusional} & English & 6920 & 872 & 1821 & 27.7 & 28.0 & 27.6\\
# \fusional{Fusional} & Russian & 2938 & 424 & 867 & 1120.1 & 1123.0 & 942.0\\
# \fusional{Fusional} & Slovak & 3724 & 532 & 1064 & 33.0 & 32.3 & 34.9\\
# \fusional{Fusional} & Croatian & 1507 & 214 & 437 & 55.2 & 56.7 & 51.8\\
# \isolating{Isolating} & Chinese & 19292 & 2756 & 5513 & 80.3 & 79.5 & 80.2\\
# \isolating{Isolating} & Vietnamese & 2384 & 331 & 685 & 35.8 & 41.0 & 37.4\\
# \isolating{Isolating} & Thai & 8103 & 1153 & 2344 & 52.8 & 56.3 & 56.4\\
# \agglutinative{Agglutinative} & Finnish & 1355 & 199 & 397 & 93.3 & 95.3 & 92.5\\
# \agglutinative{Agglutinative} & Basque & 789 & 113 & 227 & 21.4 & 20.9 & 20.7\\
# \agglutinative{Agglutinative} & Japanese & 10000 & 1000 & 2000 & 532.8 & 541.2 & 526.8\\
# \agglutinative{Agglutinative} & Korean & 3237 & 463 & 926 & 44.2 & 39.2 & 43.0\\
# \agglutinative{Agglutinative} & Turkish & 660 & 91 & 184 & 1217.5 & 1284.9 & 1234.1\\
# \introflexive{Introflexive} & Arabic & 35841 & 5134 & 10076 & 138.1 & 131.9 & 138.4\\
# \introflexive{Introflexive} & Hebrew & 8702 & 1240 & 2492 & 47.9 & 48.3 & 48.0\\
#                             group    language  train_examples  dev_examples  \
# 0             \fusional{Fusional}   Bulgarian            5412           838
# 1             \fusional{Fusional}     English            6920           872
# 2             \fusional{Fusional}     Russian            2938           424
# 3             \fusional{Fusional}      Slovak            3724           532
# 4             \fusional{Fusional}    Croatian            1507           214
# 5           \isolating{Isolating}     Chinese           19292          2756
# 6           \isolating{Isolating}  Vietnamese            2384           331
# 7           \isolating{Isolating}        Thai            8103          1153
# 8   \agglutinative{Agglutinative}     Finnish            1355           199
# 9   \agglutinative{Agglutinative}      Basque             789           113
# 10  \agglutinative{Agglutinative}    Japanese           10000          1000
# 11  \agglutinative{Agglutinative}      Korean            3237           463
# 12  \agglutinative{Agglutinative}     Turkish             660            91
# 13    \introflexive{Introflexive}      Arabic           35841          5134
# 14    \introflexive{Introflexive}      Hebrew            8702          1240
#
#     test_examples train_avg_tokens dev_avg_tokens test_avg_tokens
# 0            1673             19.9           18.2            19.4
# 1            1821             27.7           28.0            27.6
# 2             867           1120.1         1123.0           942.0
# 3            1064             33.0           32.3            34.9
# 4             437             55.2           56.7            51.8
# 5            5513             80.3           79.5            80.2
# 6             685             35.8           41.0            37.4
# 7            2344             52.8           56.3            56.4
# 8             397             93.3           95.3            92.5
# 9             227             21.4           20.9            20.7
# 10           2000            532.8          541.2           526.8
# 11            926             44.2           39.2            43.0
# 12            184           1217.5         1284.9          1234.1
# 13          10076            138.1          131.9           138.4
# 14           2492             47.9           48.3            48.0

# %%
utils.convert_table_to_latex(sentiment_table[["language"] + sentiment_table.columns[7:13].tolist()])
# Out:
# \fusional{Fusional} & Bulgarian & 599 & 0.55 & 471 & 3.08 & 556 & 1.71\\
# \fusional{Fusional} & English & 3257 & 1.70 & 2416 & 9.91 & 2876 & 5.73\\
# \fusional{Fusional} & Russian & 2005 & 0.06 & 1838 & 0.39 & 1879 & 0.23\\
# \fusional{Fusional} & Slovak & 1460 & 1.19 & 990 & 5.76 & 1143 & 3.08\\
# \fusional{Fusional} & Croatian & 1409 & 1.69 & 946 & 7.79 & 1055 & 4.66\\
# \isolating{Isolating} & Chinese & 606 & 0.04 & 856 & 0.39 & 935 & 0.21\\
# \isolating{Isolating} & Vietnamese & 1026 & 1.20 & 732 & 5.40 & 797 & 3.11\\
# \isolating{Isolating} & Thai & 1445 & 0.34 & 597 & 0.92 & 894 & 0.68\\
# \agglutinative{Agglutinative} & Finnish & 1704 & 1.35 & 1215 & 6.41 & 1320 & 3.59\\
# \agglutinative{Agglutinative} & Basque & 851 & 5.03 & 461 & 19.48 & 607 & 12.93\\
# \agglutinative{Agglutinative} & Japanese & 3413 & 0.06 & 1928 & 0.36 & 2288 & 0.22\\
# \agglutinative{Agglutinative} & Korean & 445 & 0.31 & 507 & 2.79 & 448 & 1.12\\
# \agglutinative{Agglutinative} & Turkish & 2851 & 0.35 & 1894 & 1.62 & 2049 & 0.90\\
# \introflexive{Introflexive} & Arabic & 246 & 0.00 & 249 & 0.04 & 236 & 0.02\\
# \introflexive{Introflexive} & Hebrew & 391 & 0.09 & 539 & 0.90 & 560 & 0.47\\
#                             group    language  train_hapaxes train_hapaxes(%)  \
# 0             \fusional{Fusional}   Bulgarian            599             0.55
# 1             \fusional{Fusional}     English           3257             1.70
# 2             \fusional{Fusional}     Russian           2005             0.06
# 3             \fusional{Fusional}      Slovak           1460             1.19
# 4             \fusional{Fusional}    Croatian           1409             1.69
# 5           \isolating{Isolating}     Chinese            606             0.04
# 6           \isolating{Isolating}  Vietnamese           1026             1.20
# 7           \isolating{Isolating}        Thai           1445             0.34
# 8   \agglutinative{Agglutinative}     Finnish           1704             1.35
# 9   \agglutinative{Agglutinative}      Basque            851             5.03
# 10  \agglutinative{Agglutinative}    Japanese           3413             0.06
# 11  \agglutinative{Agglutinative}      Korean            445             0.31
# 12  \agglutinative{Agglutinative}     Turkish           2851             0.35
# 13    \introflexive{Introflexive}      Arabic            246             0.00
# 14    \introflexive{Introflexive}      Hebrew            391             0.09
#
#     dev_hapaxes dev_hapaxes(%)  test_hapaxes test_hapaxes(%)
# 0           471           3.08           556            1.71
# 1          2416           9.91          2876            5.73
# 2          1838           0.39          1879            0.23
# 3           990           5.76          1143            3.08
# 4           946           7.79          1055            4.66
# 5           856           0.39           935            0.21
# 6           732           5.40           797            3.11
# 7           597           0.92           894            0.68
# 8          1215           6.41          1320            3.59
# 9           461          19.48           607           12.93
# 10         1928           0.36          2288            0.22
# 11          507           2.79           448            1.12
# 12         1894           1.62          2049            0.90
# 13          249           0.04           236            0.02
# 14          539           0.90           560            0.47

# %%
utils.convert_table_to_latex(sentiment_table[["language"] + sentiment_table.columns[13:].tolist()])
# Out:
# \fusional{Fusional} & Bulgarian & 29 & 0.03 & 3 & 0.02 & 10 & 0.03\\
# \fusional{Fusional} & English & 626 & 0.33 & 52 & 0.21 & 99 & 0.20\\
# \fusional{Fusional} & Russian & 12547 & 0.38 & 1321 & 0.28 & 3288 & 0.40\\
# \fusional{Fusional} & Slovak & 142 & 0.12 & 28 & 0.16 & 51 & 0.14\\
# \fusional{Fusional} & Croatian & 2 & 0.00 & 0 & 0.00 & 0 & 0.00\\
# \isolating{Isolating} & Chinese & 6772 & 0.44 & 1133 & 0.52 & 1734 & 0.39\\
# \isolating{Isolating} & Vietnamese & 384 & 0.45 & 51 & 0.38 & 60 & 0.23\\
# \isolating{Isolating} & Thai & 1384 & 0.32 & 193 & 0.30 & 390 & 0.30\\
# \agglutinative{Agglutinative} & Finnish & 15 & 0.01 & 2 & 0.01 & 2 & 0.01\\
# \agglutinative{Agglutinative} & Basque & 0 & 0.00 & 0 & 0.00 & 0 & 0.00\\
# \agglutinative{Agglutinative} & Japanese & 16407 & 0.31 & 1539 & 0.28 & 2825 & 0.27\\
# \agglutinative{Agglutinative} & Korean & 608 & 0.43 & 42 & 0.23 & 184 & 0.46\\
# \agglutinative{Agglutinative} & Turkish & 2272 & 0.28 & 217 & 0.19 & 695 & 0.31\\
# \introflexive{Introflexive} & Arabic & 697 & 0.01 & 89 & 0.01 & 257 & 0.02\\
# \introflexive{Introflexive} & Hebrew & 260 & 0.06 & 32 & 0.05 & 69 & 0.06\\
#                             group    language  train_unknown train_unknown(%)  \
# 0             \fusional{Fusional}   Bulgarian             29             0.03
# 1             \fusional{Fusional}     English            626             0.33
# 2             \fusional{Fusional}     Russian          12547             0.38
# 3             \fusional{Fusional}      Slovak            142             0.12
# 4             \fusional{Fusional}    Croatian              2             0.00
# 5           \isolating{Isolating}     Chinese           6772             0.44
# 6           \isolating{Isolating}  Vietnamese            384             0.45
# 7           \isolating{Isolating}        Thai           1384             0.32
# 8   \agglutinative{Agglutinative}     Finnish             15             0.01
# 9   \agglutinative{Agglutinative}      Basque              0             0.00
# 10  \agglutinative{Agglutinative}    Japanese          16407             0.31
# 11  \agglutinative{Agglutinative}      Korean            608             0.43
# 12  \agglutinative{Agglutinative}     Turkish           2272             0.28
# 13    \introflexive{Introflexive}      Arabic            697             0.01
# 14    \introflexive{Introflexive}      Hebrew            260             0.06
#
#     dev_unknown dev_unknown(%)  test_unknown test_unknown(%)
# 0             3           0.02            10            0.03
# 1            52           0.21            99            0.20
# 2          1321           0.28          3288            0.40
# 3            28           0.16            51            0.14
# 4             0           0.00             0            0.00
# 5          1133           0.52          1734            0.39
# 6            51           0.38            60            0.23
# 7           193           0.30           390            0.30
# 8             2           0.01             2            0.01
# 9             0           0.00             0            0.00
# 10         1539           0.28          2825            0.27
# 11           42           0.23           184            0.46
# 12          217           0.19           695            0.31
# 13           89           0.01           257            0.02
# 14           32           0.05            69            0.06
